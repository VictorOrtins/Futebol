# %% [markdown]
# # Imports

# %%
from ScraperFC.fbref import FBref

# %% [markdown]
# # FBRef

# %%
fbref_scrapper = FBref()

# %% [markdown]
# ## Matches

# %% [markdown]
# ### Single Match

# %%
random_match = fbref_scrapper.scrape_match("https://fbref.com/en/matches/51c34597/Fortaleza-Red-Bull-Bragantino-July-26-2025-Serie-A")

# %%
random_match.head()
# Out:
#                                                 Link                    Date  \
# 0  https://fbref.com/en/matches/51c34597/Fortalez...  Saturday July 26, 2025
#
#                                           Stage  Home Team  \
# 0  Campeonato Brasileiro Série A (Matchweek 17)  Fortaleza
#
#              Away Team Home Team ID Away Team ID Home Goals Away Goals  \
# 0  Red Bull Bragantino     a9d0ab0e     f98930d1          3          1
#
#                                    Home Player Stats  \
# 0  Summary                    Unnamed: 0_level_0 ...
#
#                                    Away Player Stats  \
# 0  Summary             Unnamed: 0_level_0 Unnamed...
#
#                                                Shots
# 0  Both       Unnamed: 0_level_0        Unnamed: ...

# %%
random_match['Home Player Stats'][0]
# Out:
# Summary                    Unnamed: 0_level_0 Unnamed: 1_level_...
# Passing                    Unnamed: 0_level_0 Unnamed: 1_level_...
# Passing types              Unnamed: 0_level_0 Unnamed: 1_level_...
# Defense                    Unnamed: 0_level_0 Unnamed: 1_level_...
# Possession                 Unnamed: 0_level_0 Unnamed: 1_level_...
# Misc                       Unnamed: 0_level_0 Unnamed: 1_level_...
# Keeper             Unnamed: 0_level_0 Unnamed: 1_level_0 Unname...
# dtype: object

# %%
random_match['Home Player Stats'][0]['Summary'] # [0][0]
# Out:
#           Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                       Player                  #             Nation
# 0                  Deyverson               18.0             br BRA
# 1               Adam Bareiro               27.0             py PAR
# 2                      Breno               26.0             br BRA
# 3               José Herrera               80.0             ar ARG
# 4                    Marinho               11.0             br BRA
# 5               Yago Pikachu               22.0             br BRA
# 6   Matheus Pereira da Silva                5.0             br BRA
# 7           Matheus Rossetto               20.0             br BRA
# 8                Lucas Sasha               88.0             br BRA
# 9           Tomas Pochettino                7.0             ar ARG
# 10               Lucca Prior               38.0             br BRA
# 11             Diogo Barbosa               16.0             br BRA
# ...

# %%
random_match['Home Player Stats'][0]['Passing'] # [0][1]
# Out:
#           Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                       Player                  #             Nation
# 0                  Deyverson               18.0             br BRA
# 1               Adam Bareiro               27.0             py PAR
# 2                      Breno               26.0             br BRA
# 3               José Herrera               80.0             ar ARG
# 4                    Marinho               11.0             br BRA
# 5               Yago Pikachu               22.0             br BRA
# 6   Matheus Pereira da Silva                5.0             br BRA
# 7           Matheus Rossetto               20.0             br BRA
# 8                Lucas Sasha               88.0             br BRA
# 9           Tomas Pochettino                7.0             ar ARG
# 10               Lucca Prior               38.0             br BRA
# 11             Diogo Barbosa               16.0             br BRA
# ...

# %%
random_match['Home Player Stats'][0]['Passing types'] # [0][2]
# Out:
#           Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                       Player                  #             Nation
# 0                  Deyverson               18.0             br BRA
# 1               Adam Bareiro               27.0             py PAR
# 2                      Breno               26.0             br BRA
# 3               José Herrera               80.0             ar ARG
# 4                    Marinho               11.0             br BRA
# 5               Yago Pikachu               22.0             br BRA
# 6   Matheus Pereira da Silva                5.0             br BRA
# 7           Matheus Rossetto               20.0             br BRA
# 8                Lucas Sasha               88.0             br BRA
# 9           Tomas Pochettino                7.0             ar ARG
# 10               Lucca Prior               38.0             br BRA
# 11             Diogo Barbosa               16.0             br BRA
# ...

# %% [markdown]
# ### Multiple Matches

# %%
from ScraperFC.fbref import comps

# %%
comps
# Out:
# {'Copa Libertadores': {'history url': 'https://fbref.com/en/comps/14/history/Copa-Libertadores-Seasons',
#   'finders': ['Copa-Libertadores']},
#  'Champions League': {'history url': 'https://fbref.com/en/comps/8/history/Champions-League-Seasons',
#   'finders': ['European-Cup', 'Champions-League']},
#  'Europa League': {'history url': 'https://fbref.com/en/comps/19/history/Europa-League-Seasons',
#   'finders': ['UEFA-Cup', 'Europa-League']},
#  'Europa Conference League': {'history url': 'https://fbref.com/en/comps/882/history/Europa-Conference-League-Seasons',
#   'finders': ['Europa-Conference-League']},
#  'World Cup': {'history url': 'https://fbref.com/en/comps/1/history/World-Cup-Seasons',
#   'finders': ['World-Cup']},
#  'Copa America': {'history url': 'https://fbref.com/en/comps/685/history/Copa-America-Seasons',
#   'finders': ['Copa-America']},
#  'Euros': {'history url': 'https://fbref.com/en/comps/676/history/European-Championship-Seasons',
# ...

# %% [markdown]
# 22 min e 6.6s para 155 partidas
#
# Média de 8s por partida

# %%
libertadores_df = fbref_scrapper.scrape_matches("2019", "Copa Libertadores")
# Out:
# 2019 Copa Libertadores matches: 100%|██████████| 155/155 [21:42<00:00,  8.40s/it]

# %%
libertadores_df.head()
# Out:
#                                                 Link  \
# 0  https://fbref.com/en/matches/8317cdff/Deportiv...
# 1  https://fbref.com/en/matches/78257413/Flamengo...
# 2  https://fbref.com/en/matches/4035e430/Flamengo...
# 3  https://fbref.com/en/matches/bb138eb1/CS-Emele...
# 4  https://fbref.com/en/matches/7b835fcd/River-Pl...
#
#                          Date                                       Stage  \
# 0        Friday March 8, 2019  Copa Libertadores de América (Group stage)
# 1  Saturday November 23, 2019        Copa Libertadores de América (Final)
# 2     Thursday April 11, 2019  Copa Libertadores de América (Group stage)
# 3     Thursday April 11, 2019  Copa Libertadores de América (Group stage)
# 4     Thursday April 11, 2019  Copa Libertadores de América (Group stage)
#
#         Home Team       Away Team Home Team ID Away Team ID Home Goals  \
# 0  Deportivo Lara       CS Emelec     6236a52b     c1f8ae36          0
# ...

# %%
libertadores_df['Home Player Stats'][1][0]
# Out:
# /tmp/ipykernel_75404/3559002015.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   libertadores_df['Home Player Stats'][1][0]
#         Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                     Player                  #             Nation
# 0          Gabriel Barbosa                9.0             br BRA
# 1           Bruno Henrique               27.0             br BRA
# 2   Giorgian De Arrascaeta               14.0             uy URU
# 3    Robert Piris Da Motta               25.0             py PAR
# 4          Everton Ribeiro                7.0             br BRA
# 5                   Gerson               15.0             br BRA
# 6                    Diego               10.0             br BRA
# 7             Willian Arão                5.0             br BRA
# ...

# %%
libertadores_df['Away Player Stats'][1][0]
# Out:
# /tmp/ipykernel_75404/1403239699.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   libertadores_df['Away Player Stats'][1][0]
#        Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Player                  #             Nation
# 0           Matías Suárez                7.0             ar ARG
# 1            Rafael Borré               19.0             co COL
# 2            Lucas Pratto               27.0             ar ARG
# 3      Nicolás De La Cruz               11.0             uy URU
# 4       Exequiel Palacios               15.0             ar ARG
# 5       Ignacio Fernández               26.0             ar ARG
# 6          Julián Álvarez                9.0             ar ARG
# 7              Enzo Pérez               24.0             ar ARG
# ...

# %%
libertadores_df['Shots'][1][0]
# Out:
# /tmp/ipykernel_75404/1843766331.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   libertadores_df['Shots'][1][0]
#    Unnamed: 0_level_0      Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Minute                  Player              Squad
# 0                  10          Bruno Henrique           Flamengo
# 1                  14            Rafael Borré        River Plate
# 2                  26           Matías Suárez        River Plate
# 3                  36       Exequiel Palacios        River Plate
# 4                 NaN                     NaN                NaN
# 5                  47         Gabriel Barbosa           Flamengo
# 6                  51           Matías Suárez        River Plate
# 7                  53       Exequiel Palacios        River Plate
# ...

# %% [markdown]
# ## League Table

# %% [markdown]
# ### League Format

# %%
belgian_league_df = fbref_scrapper.scrape_league_table("2024-2025", "Belgian Pro League")

# %%
belgian_league_df, len(belgian_league_df)
# Out:
# ([      Rk           Squad    MP     W     D     L    GF    GA    GD   Pts  \
#   0    1.0            Genk  30.0  21.0   5.0   4.0  55.0  33.0  22.0  68.0
#   1    2.0     Club Brugge  30.0  17.0   8.0   5.0  65.0  36.0  29.0  59.0
#   2    3.0        Union SG  30.0  15.0  10.0   5.0  49.0  25.0  24.0  55.0
#   3    4.0      Anderlecht  30.0  15.0   6.0   9.0  50.0  27.0  23.0  51.0
#   4    5.0         Antwerp  30.0  12.0  10.0   8.0  47.0  32.0  15.0  46.0
#   5    6.0            Gent  30.0  11.0  12.0   7.0  41.0  33.0   8.0  45.0
#   6    7.0  Standard Liège  30.0  10.0   9.0  11.0  22.0  35.0 -13.0  39.0
#   7    8.0        Mechelen  30.0  10.0   8.0  12.0  45.0  40.0   5.0  38.0
#   8    9.0        Westerlo  30.0  10.0   7.0  13.0  50.0  49.0   1.0  37.0
#   9   10.0       Charleroi  30.0  10.0   7.0  13.0  36.0  36.0   0.0  37.0
#   10  11.0       OH Leuven  30.0   8.0  13.0   9.0  28.0  33.0  -5.0  37.0
# ...

# %% [markdown]
# Tabela preliminar

# %%
belgian_league_df[0]
# Out:
#       Rk           Squad    MP     W     D     L    GF    GA    GD   Pts  \
# 0    1.0            Genk  30.0  21.0   5.0   4.0  55.0  33.0  22.0  68.0
# 1    2.0     Club Brugge  30.0  17.0   8.0   5.0  65.0  36.0  29.0  59.0
# 2    3.0        Union SG  30.0  15.0  10.0   5.0  49.0  25.0  24.0  55.0
# 3    4.0      Anderlecht  30.0  15.0   6.0   9.0  50.0  27.0  23.0  51.0
# 4    5.0         Antwerp  30.0  12.0  10.0   8.0  47.0  32.0  15.0  46.0
# 5    6.0            Gent  30.0  11.0  12.0   7.0  41.0  33.0   8.0  45.0
# 6    7.0  Standard Liège  30.0  10.0   9.0  11.0  22.0  35.0 -13.0  39.0
# 7    8.0        Mechelen  30.0  10.0   8.0  12.0  45.0  40.0   5.0  38.0
# 8    9.0        Westerlo  30.0  10.0   7.0  13.0  50.0  49.0   1.0  37.0
# 9   10.0       Charleroi  30.0  10.0   7.0  13.0  36.0  36.0   0.0  37.0
# 10  11.0       OH Leuven  30.0   8.0  13.0   9.0  28.0  33.0  -5.0  37.0
# 11  12.0          Dender  30.0   8.0   8.0  14.0  33.0  51.0 -18.0  32.0
# ...

# %% [markdown]
# Grupo da Champions

# %%
belgian_league_df[1]
# Out:
#    Rk        Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP    xG   xGA   xGD  \
# 0   1     Union SG   9  8  1  0  19   2  17   53    5.89  16.9   7.8   9.1
# 1   2  Club Brugge   9  7  1  1  20   5  15   52    5.78  23.0   9.6  13.3
# 2   3         Genk   9  3  1  5  12  10   2   44    4.89  13.7  15.2  -1.4
# 3   4   Anderlecht   9  3  1  5  11  11   0   36    4.00  11.4  14.5  -3.1
# 4   5      Antwerp   9  2  2  5   9  17  -8   31    3.44  12.3  17.0  -4.7
# 5   6         Gent   9  1  0  8   3  29 -26   26    2.89  10.0  23.3 -13.2
#
#    xGD/90                                              Notes
# 0    0.91  Began with 28 points, → Champions League via l...
# 1    1.33  Began with 30 points, → Champions League via l...
# 2   -0.14  Began with 34 points, → Europa League via leag...
# 3   -0.31  Began with 26 points, → Europa League via leag...
# 4   -0.47  Began with 23 points, → European competition p...
# 5   -1.32                               Began with 23 points

# %% [markdown]
# Grupo de Conference League

# %%
belgian_league_df[2]
# Out:
#    Rk           Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP    xG   xGA  xGD  \
# 0   1       Charleroi   9  5  3  1  17   9   8   37    4.11  19.2  15.5  3.7
# 1   2        Westerlo   9  3  4  2  19  16   3   32    3.56  20.1  16.6  3.5
# 2   3        Mechelen   9  2  5  2  15  15   0   30    3.33  22.0  14.8  7.2
# 3   4          Dender   9  3  3  3  18  19  -1   28    3.11  15.3  19.8 -4.5
# 4   5       OH Leuven   9  1  5  3  10  17  -7   27    3.00  14.6  19.8 -5.2
# 5   6  Standard Liège   9  0  6  3   5   8  -3   26    2.89   9.0  13.8 -4.7
#
#    xGD/90                                              Notes
# 0    0.37  Began with 19 points, → European competition p...
# 1    0.35                               Began with 19 points
# 2    0.72                               Began with 19 points
# 3   -0.45                               Began with 16 points
# 4   -0.52                               Began with 19 points
# 5   -0.47                               Began with 20 points

# %% [markdown]
# Grupo de Rebaixamento

# %%
belgian_league_df[3]
# Out:
#    Rk          Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0   1   Sint-Truiden  36  10  11  15  50  66 -16   41    1.14  12.0   6.5
# 1   2  Cercle Brugge  36   9  12  15  39  57 -18   39    1.08  10.9   7.9
# 2   3       Kortrijk  36  10   7  19  40  63 -23   37    1.03   6.6   9.0
# 3   4      Beerschot  36   5   9  22  36  70 -34   24    0.67   7.6  13.6
#
#    xGD  xGD/90                                         Notes
# 0  5.5    0.91                                           NaN
# 1  3.0    0.51  → Belgian 1/2 Relegation/Promotion play-offs
# 2 -2.5   -0.42                                     Relegated
# 3 -6.0   -1.00                                     Relegated

# %% [markdown]
# ### Knockout Format

# %%
world_cup_df = fbref_scrapper.scrape_league_table("2014","World Cup")

# %%
world_cup_df, len(world_cup_df)
# Out:
# ([   Rk        Squad  MP  W  D  L  GF  GA  GD  Pts          Notes
#   0   1    br Brazil   3  2  1  0   7   2   5    7  → Round of 16
#   1   2    mx Mexico   3  2  1  0   4   1   3    7  → Round of 16
#   2   3   hr Croatia   3  1  0  2   6   6   0    3            NaN
#   3   4  cm Cameroon   3  0  0  3   1   9  -8    0            NaN,
#      Rk           Squad  MP  W  D  L  GF  GA  GD  Pts          Notes
#   0   1  nl Netherlands   3  3  0  0  10   3   7    9  → Round of 16
#   1   2        cl Chile   3  2  0  1   5   3   2    6  → Round of 16
#   2   3        es Spain   3  1  0  2   4   7  -3    3            NaN
#   3   4    au Australia   3  0  0  3   3   9  -6    0            NaN,
#      Rk             Squad  MP  W  D  L  GF  GA  GD  Pts          Notes
#   0   1       co Colombia   3  3  0  0   9   2   7    9  → Round of 16
#   1   2         gr Greece   3  1  1  1   2   4  -2    4  → Round of 16
#   2   3  ci Côte d'Ivoire   3  1  0  2   4   5  -1    3            NaN
# ...

# %% [markdown]
# Group A

# %%
world_cup_df[0]
# Out:
#    Rk        Squad  MP  W  D  L  GF  GA  GD  Pts          Notes
# 0   1    br Brazil   3  2  1  0   7   2   5    7  → Round of 16
# 1   2    mx Mexico   3  2  1  0   4   1   3    7  → Round of 16
# 2   3   hr Croatia   3  1  0  2   6   6   0    3            NaN
# 3   4  cm Cameroon   3  0  0  3   1   9  -8    0            NaN

# %% [markdown]
# Group B

# %%
world_cup_df[1]
# Out:
#    Rk           Squad  MP  W  D  L  GF  GA  GD  Pts          Notes
# 0   1  nl Netherlands   3  3  0  0  10   3   7    9  → Round of 16
# 1   2        cl Chile   3  2  0  1   5   3   2    6  → Round of 16
# 2   3        es Spain   3  1  0  2   4   7  -3    3            NaN
# 3   4    au Australia   3  0  0  3   3   9  -6    0            NaN

# %% [markdown]
# Knockouts

# %%
world_cup_df[-1]
# Out:
#      Rk                Squad   MP    W    D    L    GF    GA    GD   Pts  \
# 0     1           de Germany  7.0  6.0  1.0  0.0  18.0   4.0  14.0  19.0
# 1     2         ar Argentina  7.0  5.0  1.0  1.0   8.0   4.0   4.0  16.0
# 2     3       nl Netherlands  7.0  5.0  2.0  0.0  15.0   4.0  11.0  17.0
# 3     4            br Brazil  7.0  3.0  2.0  2.0  11.0  14.0  -3.0  11.0
# 4    QF          co Colombia  5.0  4.0  0.0  1.0  12.0   4.0   8.0  12.0
# 5    QF           be Belgium  5.0  4.0  0.0  1.0   6.0   3.0   3.0  12.0
# 6    QF            fr France  5.0  3.0  1.0  1.0  10.0   3.0   7.0  10.0
# 7    QF        cr Costa Rica  5.0  2.0  3.0  0.0   5.0   2.0   3.0   9.0
# 8   R16             cl Chile  4.0  2.0  1.0  1.0   6.0   4.0   2.0   7.0
# 9   R16            mx Mexico  4.0  2.0  1.0  1.0   5.0   3.0   2.0   7.0
# 10  R16       ch Switzerland  4.0  2.0  0.0  2.0   7.0   7.0   0.0   6.0
# 11  R16           uy Uruguay  4.0  2.0  0.0  2.0   4.0   6.0  -2.0   6.0
# ...

# %% [markdown]
# ## Stats

# %% [markdown]
# ### Specific Stats

# %%
from ScraperFC.fbref import stats_categories

# %%
stats_categories
# Out:
# {'standard': {'url': 'stats', 'html': 'standard'},
#  'goalkeeping': {'url': 'keepers', 'html': 'keeper'},
#  'advanced goalkeeping': {'url': 'keepersadv', 'html': 'keeper_adv'},
#  'shooting': {'url': 'shooting', 'html': 'shooting'},
#  'passing': {'url': 'passing', 'html': 'passing'},
#  'pass types': {'url': 'passing_types', 'html': 'passing_types'},
#  'goal and shot creation': {'url': 'gca', 'html': 'gca'},
#  'defensive': {'url': 'defense', 'html': 'defense'},
#  'possession': {'url': 'possession', 'html': 'possession'},
#  'playing time': {'url': 'playingtime', 'html': 'playing_time'},
#  'misc': {'url': 'misc', 'html': 'misc'}}

# %%
br_stats_df = fbref_scrapper.scrape_stats(league="Brazilian Serie A", year="2020", stat_category="goal and shot creation")

# %%
br_stats_df, len(br_stats_df)
# Out:
# ((   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0   SCA         \
#                   Squad               # Pl                90s   SCA  SCA90
#   0      Ath Paranaense                 41               38.0   765  20.13
#   1      Atl Goianiense                 35               38.0   801  21.08
#   2    Atlético Mineiro                 34               38.0  1103  29.03
#   3               Bahia                 39               38.0   903  23.76
#   4       Botafogo (RJ)                 45               38.0   903  23.76
#   5               Ceará                 34               38.0   780  20.53
#   6         Corinthians                 36               38.0   819  21.55
#   7            Coritiba                 47               38.0   696  18.32
#   8            Flamengo                 38               38.0  1018  26.79
#   9          Fluminense                 37               38.0   766  20.16
# ...

# %% [markdown]
# Stats pró de cada time

# %%
br_stats_df[0].head(5)
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0   SCA         \
#                Squad               # Pl                90s   SCA  SCA90
# 0     Ath Paranaense                 41               38.0   765  20.13
# 1     Atl Goianiense                 35               38.0   801  21.08
# 2   Atlético Mineiro                 34               38.0  1103  29.03
# 3              Bahia                 39               38.0   903  23.76
# 4      Botafogo (RJ)                 45               38.0   903  23.76
#
#   SCA Types                           GCA       GCA Types                      \
#    PassLive PassDead  TO  Sh Fld Def  GCA GCA90  PassLive PassDead  TO Sh Fld
# 0       564       71  42  40  39   9   68  1.79        49        3  10  5   1
# 1       572       75  51  36  54  13   72  1.89        47        6   7  7   3
# 2       830       68  58  74  54  19  106  2.79        77        4   6  8   9
# ...

# %% [markdown]
# Stats de cada time contra

# %%
br_stats_df[1].head(5)
# Out:
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  SCA         \
#                  Squad               # Pl                90s  SCA  SCA90
# 0    vs Ath Paranaense                 41               38.0  849  22.34
# 1    vs Atl Goianiense                 35               38.0  857  22.55
# 2  vs Atlético Mineiro                 34               38.0  636  16.74
# 3             vs Bahia                 39               38.0  908  23.89
# 4     vs Botafogo (RJ)                 45               38.0  931  24.50
#
#   SCA Types                           GCA       GCA Types                   \
#    PassLive PassDead  TO  Sh Fld Def  GCA GCA90  PassLive PassDead  TO  Sh
# 0       594       85  51  57  47  15   61  1.61        37        7   5   8
# 1       608       91  46  54  46  12   66  1.74        43        4   8   7
# 2       472       48  38  32  38   8   77  2.03        56        6   4   8
# 3       638       96  52  49  62  11  105  2.76        65       12  10   9
# ...

# %% [markdown]
# Stats de cada jogador

# %%
br_stats_df[2]
# Out:
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                     Rk             Player             Nation
# 0                    1              Abner             br BRA
# 1                    2       Pedro Acacio             br BRA
# 2                    3       Luiz Adriano             br BRA
# 3                    4          Adryelson             br BRA
# 4                    5     Felipe Aguilar             co COL
# ..                 ...                ...                ...
# 748                749              Ytalo             br BRA
# 749                750               Yuri             br BRA
# 750                751   Federico Zaracho             ar ARG
# 751                752               Zeca             br BRA
# 752                753               Zeca             br BRA
#
#     Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
#                    Pos              Squad                Age
# ...

# %% [markdown]
# ### All Stats

# %% [markdown]
# 11 stats em 3 min e 27s
# 18s por stat

# %%
pl_stats_df = fbref_scrapper.scrape_all_stats(league="EPL", year="2024-2025")
# Out:
# 2024-2025 EPL stats: 100%|██████████| 11/11 [03:27<00:00, 18.88s/it]

# %%
pl_stats_df, len(pl_stats_df)
# Out:
# ({'standard': (   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Squad               # Pl                Age
#    0             Arsenal                 25               25.8
#    1         Aston Villa                 28               27.0
#    2         Bournemouth                 29               25.1
#    3           Brentford                 28               25.8
#    4            Brighton                 32               24.8
#    5             Chelsea                 29               23.7
#    6      Crystal Palace                 29               26.2
#    7             Everton                 26               28.0
#    8              Fulham                 26               28.1
#    9        Ipswich Town                 32               25.8
#    10     Leicester City                 32               26.6
#    11          Liverpool                 24               27.2
#    12    Manchester City                 30               26.8
# ...

# %% [markdown]
# Stats pró de cada time

# %%
pl_stats_df.keys()
# Out:
# dict_keys(['standard', 'goalkeeping', 'advanced goalkeeping', 'shooting', 'passing', 'pass types', 'goal and shot creation', 'defensive', 'possession', 'playing time', 'misc'])

# %% [markdown]
# Estatísticas de goleiros

# %%
pl_stats_df['advanced goalkeeping'], len(pl_stats_df['advanced goalkeeping'])
# Out:
# ((   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Goals             \
#                   Squad               # Pl                90s    GA PKA FK  CK
#   0             Arsenal                  1               38.0    34   3  2   8
#   1         Aston Villa                  2               38.0    51   2  1   2
#   2         Bournemouth                  3               38.0    46   4  1   5
#   3           Brentford                  2               38.0    57   1  0   2
#   4            Brighton                  2               38.0    59   9  1   4
#   5             Chelsea                  2               38.0    43   5  0   5
#   6      Crystal Palace                  1               38.0    51   1  1   5
#   7             Everton                  1               38.0    44   0  1   6
#   8              Fulham                  1               38.0    54   3  0   6
#   9        Ipswich Town                  3               38.0    82   6  0  11
# ...

# %% [markdown]
# Estatísicas dos goleiros do time

# %%
pl_stats_df['advanced goalkeeping'][0].head(5)
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Goals               \
#                Squad               # Pl                90s    GA PKA FK CK OG
# 0            Arsenal                  1               38.0    34   3  2  8  0
# 1        Aston Villa                  2               38.0    51   2  1  2  0
# 2        Bournemouth                  3               38.0    46   4  1  5  0
# 3          Brentford                  2               38.0    57   1  0  2  3
# 4           Brighton                  2               38.0    59   9  1  4  2
#
#   Expected           ... Goal Kicks                Crosses           Sweeper  \
#       PSxG PSxG/SoT  ...        Att Launch% AvgLen     Opp Stp  Stp%    #OPA
# 0     35.1     0.28  ...        200    50.0   38.6     402  53  13.2      66
# 1     52.1     0.32  ...        299    41.8   35.1     538  59  11.0      35
# 2     54.8     0.30  ...        266    47.7   39.4     460  25   5.4      62
# ...

# %% [markdown]
# Estatísticas contra os goleiros do time

# %%
pl_stats_df['advanced goalkeeping'][1].head(5)
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Goals             \
#                Squad               # Pl                90s    GA PKA FK  CK
# 0         vs Arsenal                  1               38.0    69   2  0  12
# 1     vs Aston Villa                  2               38.0    58   3  0   9
# 2     vs Bournemouth                  3               38.0    58   6  1   5
# 3       vs Brentford                  2               38.0    66   5  0   5
# 4        vs Brighton                  2               38.0    66   7  2   6
#
#      Expected           ... Goal Kicks                Crosses           \
#   OG     PSxG PSxG/SoT  ...        Att Launch% AvgLen     Opp Stp Stp%
# 0  2     61.5     0.35  ...        309    50.8   39.1     602  33  5.5
# 1  2     57.7     0.33  ...        262    42.0   34.2     462  40  8.7
# 2  1     65.0     0.30  ...        343    48.1   37.5     637  47  7.4
# 3  1     67.3     0.36  ...        252    45.6   36.6     534  44  8.2
# ...

# %%
pl_stats_df['advanced goalkeeping'][2].head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                   Rk             Player             Nation                Pos
# 0                  1            Alisson             br BRA                 GK
# 1                  2    Alphonse Areola             fr FRA                 GK
# 2                  3  Kepa Arrizabalaga             es ESP                 GK
# 3                  4     Brandon Austin            eng ENG                 GK
# 4                  5     Altay Bayındır             tr TUR                 GK
#
#   Unnamed: 4_level_0 Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
#                Squad                Age               Born                90s
# 0          Liverpool                 31               1992               27.9
# 1           West Ham                 31               1993               25.1
# 2        Bournemouth                 29               1994               31.0
# ...
